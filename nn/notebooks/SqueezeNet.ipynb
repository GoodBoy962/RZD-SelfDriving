# %%
import keras.callbacks
import tensorflow as tf

from keras.models import Model
from keras.layers import UpSampling2D, ZeroPadding2D, Conv2DTranspose, Input, concatenate
from keras.layers.core import Activation 
from keras.layers.convolutional import Conv2D, MaxPooling2D, Convolution2D
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.preprocessing import image
from keras import backend as K
from keras.callbacks import TensorBoard, EarlyStopping
from keras.optimizers import Adam
from keras.losses import binary_crossentropy
from keras.engine.topology import get_source_inputs

from sklearn.model_selection import train_test_split

import os 
import sys
import numpy as np 

import matplotlib.pyplot as plt

import warnings

# %%
print(sys.version)
print(keras.__version__)
#print(tf.__version__)
# Out:
# 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]
# 2.2.4

# %% [markdown]
# # Load & preproc data

# %%
#!unzip all.zip

# %%
path = r'C:\Users\RZD.GENERATION\Downloads\data\all' 
pathX = path + r'\train'
pathY = path + r'\trainmask'

#path = '/content/all'
#pathX = path + '/train'
#pathY = path + '/trainmask'
 
data_names = os.listdir(pathX)
dataX = []
dataY = []

h = 256
w = 256
 
for count, smpl in enumerate(data_names): #some preprac can be done here
    img = image.img_to_array(image.load_img(pathX+"/"+smpl))  #.resize((h,w)))
    mask = image.img_to_array(image.load_img(pathY+"/"+smpl))  #.resize((h,w)))
    if img.shape[0] not in [360, h]:
        img = img[8:,:,:]
        mask = mask[8:,:,:]
    dataX.append(img)
    dataY.append(mask)
    if count == 1000:
        break

dataX = np.array(dataX)/255.
dataY = (np.array(dataY)[:,:,:,0])/255. 
dataY = np.expand_dims(dataY, axis=3)

(x_train, x_test, y_train, y_test) = train_test_split(dataX, dataY, test_size=0.25)

# %% [markdown]
# ## Augmentation

# %%
#flip
for i in range(len(dataX)):
    dataX.append(tf.image.flip_left_right(dataX[i]))
    dataY.append(tf.image.flip_left_right(dataY[i]))
    

#change brightness
for i in range(len(dataX)):
    dataX.append(tf.image.random_brightness(dataX[i], 0.05))
    dataY.append(dataY[i])

# %%
#dataX = np.array(dataX)/255.
#dataY = (np.array(dataY)[:,:,:,0])/255. 
#dataY = np.expand_dims(dataY, axis=3)

#(x_train, x_test, y_train, y_test) = train_test_split(dataX, dataY, test_size=0.25)

# %%
img_rows, img_cols = x_train.shape[1], x_train.shape[2] 
channels = x_train.shape[3]

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], channels, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], channels, img_rows, img_cols)
    input_shape = (channels, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)
    input_shape = (img_rows, img_cols, channels)

# %%
print('train:')
print(x_train.shape)
print(y_train.shape)
print('test:')
print(x_test.shape)
print(y_test.shape)
# Out:
# train:
# (750, 360, 480, 3)
# (750, 360, 480, 1)
# test:
# (251, 360, 480, 3)
# (251, 360, 480, 1)

# %%
def viz_res(model, n=10):
    y_test1 = np.array([i[:,:,0] for i in y_test])

    segm_imgs = model.predict(x_test[:n])
    #for sigmoid activ
    segm_imgs[segm_imgs < 0.5] = 0.
    segm_imgs[segm_imgs >= 0.5] = 1.
    segm_imgs = np.array([i[:,:,0] for i in segm_imgs])

    for i in range(n):
        fig, axarr = plt.subplots(1, 3, figsize=(30, 30))
        axarr[0].imshow(x_test[i])
        axarr[1].imshow(y_test1[i], cmap='gray')
        axarr[2].imshow(segm_imgs[i], cmap='gray') 
        for j in range(3):
            axarr[j].get_xaxis().set_visible(False)
            axarr[j].get_yaxis().set_visible(False)
        plt.show()

# %% [markdown]
# # Loss & metrics

# %%
def iou(y_true, y_pred, smooth=1):
    y_pred = K.round(y_pred) ###
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum( y_pred_f) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return iou

# %%
def f1(y_true, y_pred):
    y_pred = K.round(y_pred)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    tp = K.sum(y_true_f*y_pred_f)
    fp = K.sum((1-y_true_f)*y_pred_f)
    fn = K.sum(y_true_f*(1-y_pred_f))

    p = tp / (tp + fp + K.epsilon())
    r = tp / (tp + fn + K.epsilon())

    return 2*p*r / (p+r+K.epsilon())

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_pred = K.round(y_pred)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_coef_loss(y_true, y_pred)

# %%
def kulch_coef(y_true, y_pred, smooth=1):
    y_pred = K.round(y_pred)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) - 2*intersection + smooth)

def kulch_coef_loss(y_true, y_pred):
    return 1-kulch_coef(y_true, y_pred)

def bce_kulch_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + kulch_coef_loss(y_true, y_pred)

# %%
earlyStopping = EarlyStopping(monitor='val_loss', 
                              patience=2, #number of epochs with no improvement after which training will be stopped
                              verbose=1, #training will stop when the quantity monitored has stopped decreasing
                              min_delta = 0.0001,
                              mode='min')

#modelCheckpoint = ModelCheckpoint(checkpoint_loc,
#                                  monitor = 'val_loss', 
#                                  save_best_only = True, 
#                                  mode = 'min', 
#                                  verbose = 1,
#                                  save_weights_only = True)

tensorboard = TensorBoard(log_dir=r'C:\Users\RZD.GENERATION\Downloads\keras_pract\caffenet_log', histogram_freq=0, write_graph=True, write_images=True)

callbacks_list = [earlyStopping, tensorboard]

# %% [markdown]
# # SqueezeNet for segmentation

# %%
#modified from keras squeezenet pack

sq1x1 = 'squeeze1x1'
exp1x1 = 'expand1x1'
exp3x3 = 'expand3x3'
relu = 'relu_'

# Modular function for Fire Node

def fire_module(x, fire_id, squeeze=16, expand=64, add=''):
    s_id = 'fire' + str(fire_id) + '/'

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3
    
    x = Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1 + add)(x)
    x = Activation('relu', name=s_id + relu + sq1x1 + add)(x)

    left = Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1 + add)(x)
    left = Activation('relu', name=s_id + relu + exp1x1 + add)(left)

    right = Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3 + add)(x)
    right = Activation('relu', name=s_id + relu + exp3x3 + add)(right)

    x = concatenate([left, right], axis=channel_axis, name=s_id + 'concat' + add)
    return x


# Original SqueezeNet from paper.

def SqueezeNet(input_tensor=None, 
               input_shape=None,
              dec='my'): #dec from ['my', 'FCN8', 'FCN32']
   
    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor
            
    #encoder

    x = Convolution2D(64, (3, 3), strides=(2, 2), padding='valid', name='conv1')(img_input)
    x = Activation('relu', name='relu_conv1')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5')(x)

    x = fire_module(x, fire_id=6, squeeze=48, expand=192)
    x = fire_module(x, fire_id=7, squeeze=48, expand=192)
    x = fire_module(x, fire_id=8, squeeze=64, expand=256)
    x = fire_module(x, fire_id=9, squeeze=64, expand=256)
    
    #decoder
    
    if dec == 'my':
        x = fire_module(x, fire_id=9, squeeze=64, expand=256, add='dec')
        x = fire_module(x, fire_id=8, squeeze=64, expand=256, add='dec')
        x = fire_module(x, fire_id=7, squeeze=48, expand=192, add='dec')
        x = fire_module(x, fire_id=6, squeeze=48, expand=192, add='dec')
    
        x = UpSampling2D(name='upsample1')(x)
        x = ZeroPadding2D((1,0))(x) 
    
        x = fire_module(x, fire_id=5, squeeze=32, expand=128, add='dec')
        x = fire_module(x, fire_id=4, squeeze=32, expand=128, add='dec')
    
        x = UpSampling2D(name='upsample2')(x) 
        x = ZeroPadding2D((0,1))(x)
    
        x = fire_module(x, fire_id=3, squeeze=16, expand=64, add='dec')
        x = fire_module(x, fire_id=2, squeeze=16, expand=64, add='dec')
    
        x = UpSampling2D(name='upsample3')(x)
        x = ZeroPadding2D((2,2))(x)
    
        x = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same', name='conv_prefinal')(x) #not valid here
        
    if dec == 'FCN32': #needed to be resized 198x198
        x = Conv2DTranspose(1, (3, 3), strides=(18, 18), padding='same', name='conv_prefinal')(x)
        
    #if dec == 'FCN8': #needed to be resized
        #x = Conv2DTranspose(pool2.get_shape().as_list()[-1], (0, 2), strides=(2, 2), padding='valid', name='transpose1')(x)
        #x = Add()([x, pool2])
        #x = Conv2DTranspose(pool1.get_shape().as_list()[-1], (2, 1), strides=(2, 2), padding='same', name='transpose2')(x)
        #x = Add()([x, pool1])
        #x = ZeroPadding2D((1,1))(x)
        #x = Conv2DTranspose(64, (16, 16), strides=(8, 8), padding='same', name='transpose3')(x)
     
    model = Conv2D(1, (3, 3), padding='same', activation='sigmoid', name='conv_final')(x)     

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    model = Model(inputs, model, name='squeezenet')
    
    model.compile(loss=bce_kulch_loss, optimizer=Adam(lr=1e-4), metrics=[f1, iou])

    return model

# %%
warnings.filterwarnings('ignore')

batch_size = 64
epochs = 5

model = SqueezeNet(input_shape=(360, 480, 3))

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 360, 480, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 179, 239, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# relu_conv1 (Activation)         (None, 179, 239, 64) 0           conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 89, 119, 64)  0           relu_conv1[0][0]
# __________________________________________________________________________________________________
# fire2/squeeze1x1 (Conv2D)       (None, 89, 119, 16)  1040        pool1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_squeeze1x1 (Activati (None, 89, 119, 16)  0           fire2/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand1x1 (Conv2D)        (None, 89, 119, 64)  1088        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/expand3x3 (Conv2D)        (None, 89, 119, 64)  9280        fire2/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand1x1 (Activatio (None, 89, 119, 64)  0           fire2/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand3x3 (Activatio (None, 89, 119, 64)  0           fire2/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire2/concat (Concatenate)      (None, 89, 119, 128) 0           fire2/relu_expand1x1[0][0]
#                                                                  fire2/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/squeeze1x1 (Conv2D)       (None, 89, 119, 16)  2064        fire2/concat[0][0]
# __________________________________________________________________________________________________
# fire3/relu_squeeze1x1 (Activati (None, 89, 119, 16)  0           fire3/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand1x1 (Conv2D)        (None, 89, 119, 64)  1088        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/expand3x3 (Conv2D)        (None, 89, 119, 64)  9280        fire3/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand1x1 (Activatio (None, 89, 119, 64)  0           fire3/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand3x3 (Activatio (None, 89, 119, 64)  0           fire3/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire3/concat (Concatenate)      (None, 89, 119, 128) 0           fire3/relu_expand1x1[0][0]
#                                                                  fire3/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 44, 59, 128)  0           fire3/concat[0][0]
# __________________________________________________________________________________________________
# fire4/squeeze1x1 (Conv2D)       (None, 44, 59, 32)   4128        pool3[0][0]
# __________________________________________________________________________________________________
# fire4/relu_squeeze1x1 (Activati (None, 44, 59, 32)   0           fire4/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand1x1 (Conv2D)        (None, 44, 59, 128)  4224        fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/expand3x3 (Conv2D)        (None, 44, 59, 128)  36992       fire4/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand1x1 (Activatio (None, 44, 59, 128)  0           fire4/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand3x3 (Activatio (None, 44, 59, 128)  0           fire4/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire4/concat (Concatenate)      (None, 44, 59, 256)  0           fire4/relu_expand1x1[0][0]
#                                                                  fire4/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/squeeze1x1 (Conv2D)       (None, 44, 59, 32)   8224        fire4/concat[0][0]
# __________________________________________________________________________________________________
# fire5/relu_squeeze1x1 (Activati (None, 44, 59, 32)   0           fire5/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand1x1 (Conv2D)        (None, 44, 59, 128)  4224        fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/expand3x3 (Conv2D)        (None, 44, 59, 128)  36992       fire5/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand1x1 (Activatio (None, 44, 59, 128)  0           fire5/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand3x3 (Activatio (None, 44, 59, 128)  0           fire5/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire5/concat (Concatenate)      (None, 44, 59, 256)  0           fire5/relu_expand1x1[0][0]
#                                                                  fire5/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# pool5 (MaxPooling2D)            (None, 21, 29, 256)  0           fire5/concat[0][0]
# __________________________________________________________________________________________________
# fire6/squeeze1x1 (Conv2D)       (None, 21, 29, 48)   12336       pool5[0][0]
# __________________________________________________________________________________________________
# fire6/relu_squeeze1x1 (Activati (None, 21, 29, 48)   0           fire6/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand1x1 (Conv2D)        (None, 21, 29, 192)  9408        fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/expand3x3 (Conv2D)        (None, 21, 29, 192)  83136       fire6/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand1x1 (Activatio (None, 21, 29, 192)  0           fire6/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand3x3 (Activatio (None, 21, 29, 192)  0           fire6/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire6/concat (Concatenate)      (None, 21, 29, 384)  0           fire6/relu_expand1x1[0][0]
#                                                                  fire6/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/squeeze1x1 (Conv2D)       (None, 21, 29, 48)   18480       fire6/concat[0][0]
# __________________________________________________________________________________________________
# fire7/relu_squeeze1x1 (Activati (None, 21, 29, 48)   0           fire7/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand1x1 (Conv2D)        (None, 21, 29, 192)  9408        fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/expand3x3 (Conv2D)        (None, 21, 29, 192)  83136       fire7/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand1x1 (Activatio (None, 21, 29, 192)  0           fire7/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand3x3 (Activatio (None, 21, 29, 192)  0           fire7/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire7/concat (Concatenate)      (None, 21, 29, 384)  0           fire7/relu_expand1x1[0][0]
#                                                                  fire7/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/squeeze1x1 (Conv2D)       (None, 21, 29, 64)   24640       fire7/concat[0][0]
# __________________________________________________________________________________________________
# fire8/relu_squeeze1x1 (Activati (None, 21, 29, 64)   0           fire8/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand1x1 (Conv2D)        (None, 21, 29, 256)  16640       fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/expand3x3 (Conv2D)        (None, 21, 29, 256)  147712      fire8/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand1x1 (Activatio (None, 21, 29, 256)  0           fire8/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand3x3 (Activatio (None, 21, 29, 256)  0           fire8/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire8/concat (Concatenate)      (None, 21, 29, 512)  0           fire8/relu_expand1x1[0][0]
#                                                                  fire8/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/squeeze1x1 (Conv2D)       (None, 21, 29, 64)   32832       fire8/concat[0][0]
# __________________________________________________________________________________________________
# fire9/relu_squeeze1x1 (Activati (None, 21, 29, 64)   0           fire9/squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand1x1 (Conv2D)        (None, 21, 29, 256)  16640       fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/expand3x3 (Conv2D)        (None, 21, 29, 256)  147712      fire9/relu_squeeze1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand1x1 (Activatio (None, 21, 29, 256)  0           fire9/expand1x1[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand3x3 (Activatio (None, 21, 29, 256)  0           fire9/expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/concat (Concatenate)      (None, 21, 29, 512)  0           fire9/relu_expand1x1[0][0]
#                                                                  fire9/relu_expand3x3[0][0]
# __________________________________________________________________________________________________
# fire9/squeeze1x1dec (Conv2D)    (None, 21, 29, 64)   32832       fire9/concat[0][0]
# __________________________________________________________________________________________________
# fire9/relu_squeeze1x1dec (Activ (None, 21, 29, 64)   0           fire9/squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire9/expand1x1dec (Conv2D)     (None, 21, 29, 256)  16640       fire9/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire9/expand3x3dec (Conv2D)     (None, 21, 29, 256)  147712      fire9/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand1x1dec (Activa (None, 21, 29, 256)  0           fire9/expand1x1dec[0][0]
# __________________________________________________________________________________________________
# fire9/relu_expand3x3dec (Activa (None, 21, 29, 256)  0           fire9/expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire9/concatdec (Concatenate)   (None, 21, 29, 512)  0           fire9/relu_expand1x1dec[0][0]
#                                                                  fire9/relu_expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire8/squeeze1x1dec (Conv2D)    (None, 21, 29, 64)   32832       fire9/concatdec[0][0]
# __________________________________________________________________________________________________
# fire8/relu_squeeze1x1dec (Activ (None, 21, 29, 64)   0           fire8/squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire8/expand1x1dec (Conv2D)     (None, 21, 29, 256)  16640       fire8/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire8/expand3x3dec (Conv2D)     (None, 21, 29, 256)  147712      fire8/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand1x1dec (Activa (None, 21, 29, 256)  0           fire8/expand1x1dec[0][0]
# __________________________________________________________________________________________________
# fire8/relu_expand3x3dec (Activa (None, 21, 29, 256)  0           fire8/expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire8/concatdec (Concatenate)   (None, 21, 29, 512)  0           fire8/relu_expand1x1dec[0][0]
#                                                                  fire8/relu_expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire7/squeeze1x1dec (Conv2D)    (None, 21, 29, 48)   24624       fire8/concatdec[0][0]
# __________________________________________________________________________________________________
# fire7/relu_squeeze1x1dec (Activ (None, 21, 29, 48)   0           fire7/squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire7/expand1x1dec (Conv2D)     (None, 21, 29, 192)  9408        fire7/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire7/expand3x3dec (Conv2D)     (None, 21, 29, 192)  83136       fire7/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand1x1dec (Activa (None, 21, 29, 192)  0           fire7/expand1x1dec[0][0]
# __________________________________________________________________________________________________
# fire7/relu_expand3x3dec (Activa (None, 21, 29, 192)  0           fire7/expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire7/concatdec (Concatenate)   (None, 21, 29, 384)  0           fire7/relu_expand1x1dec[0][0]
#                                                                  fire7/relu_expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire6/squeeze1x1dec (Conv2D)    (None, 21, 29, 48)   18480       fire7/concatdec[0][0]
# __________________________________________________________________________________________________
# fire6/relu_squeeze1x1dec (Activ (None, 21, 29, 48)   0           fire6/squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire6/expand1x1dec (Conv2D)     (None, 21, 29, 192)  9408        fire6/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire6/expand3x3dec (Conv2D)     (None, 21, 29, 192)  83136       fire6/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand1x1dec (Activa (None, 21, 29, 192)  0           fire6/expand1x1dec[0][0]
# __________________________________________________________________________________________________
# fire6/relu_expand3x3dec (Activa (None, 21, 29, 192)  0           fire6/expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire6/concatdec (Concatenate)   (None, 21, 29, 384)  0           fire6/relu_expand1x1dec[0][0]
#                                                                  fire6/relu_expand3x3dec[0][0]
# __________________________________________________________________________________________________
# upsample1 (UpSampling2D)        (None, 42, 58, 384)  0           fire6/concatdec[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 44, 58, 384)  0           upsample1[0][0]
# __________________________________________________________________________________________________
# fire5/squeeze1x1dec (Conv2D)    (None, 44, 58, 32)   12320       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# fire5/relu_squeeze1x1dec (Activ (None, 44, 58, 32)   0           fire5/squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire5/expand1x1dec (Conv2D)     (None, 44, 58, 128)  4224        fire5/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire5/expand3x3dec (Conv2D)     (None, 44, 58, 128)  36992       fire5/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand1x1dec (Activa (None, 44, 58, 128)  0           fire5/expand1x1dec[0][0]
# __________________________________________________________________________________________________
# fire5/relu_expand3x3dec (Activa (None, 44, 58, 128)  0           fire5/expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire5/concatdec (Concatenate)   (None, 44, 58, 256)  0           fire5/relu_expand1x1dec[0][0]
#                                                                  fire5/relu_expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire4/squeeze1x1dec (Conv2D)    (None, 44, 58, 32)   8224        fire5/concatdec[0][0]
# __________________________________________________________________________________________________
# fire4/relu_squeeze1x1dec (Activ (None, 44, 58, 32)   0           fire4/squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire4/expand1x1dec (Conv2D)     (None, 44, 58, 128)  4224        fire4/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire4/expand3x3dec (Conv2D)     (None, 44, 58, 128)  36992       fire4/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand1x1dec (Activa (None, 44, 58, 128)  0           fire4/expand1x1dec[0][0]
# __________________________________________________________________________________________________
# fire4/relu_expand3x3dec (Activa (None, 44, 58, 128)  0           fire4/expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire4/concatdec (Concatenate)   (None, 44, 58, 256)  0           fire4/relu_expand1x1dec[0][0]
#                                                                  fire4/relu_expand3x3dec[0][0]
# __________________________________________________________________________________________________
# upsample2 (UpSampling2D)        (None, 88, 116, 256) 0           fire4/concatdec[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 88, 118, 256) 0           upsample2[0][0]
# __________________________________________________________________________________________________
# fire3/squeeze1x1dec (Conv2D)    (None, 88, 118, 16)  4112        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# fire3/relu_squeeze1x1dec (Activ (None, 88, 118, 16)  0           fire3/squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire3/expand1x1dec (Conv2D)     (None, 88, 118, 64)  1088        fire3/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire3/expand3x3dec (Conv2D)     (None, 88, 118, 64)  9280        fire3/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand1x1dec (Activa (None, 88, 118, 64)  0           fire3/expand1x1dec[0][0]
# __________________________________________________________________________________________________
# fire3/relu_expand3x3dec (Activa (None, 88, 118, 64)  0           fire3/expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire3/concatdec (Concatenate)   (None, 88, 118, 128) 0           fire3/relu_expand1x1dec[0][0]
#                                                                  fire3/relu_expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire2/squeeze1x1dec (Conv2D)    (None, 88, 118, 16)  2064        fire3/concatdec[0][0]
# __________________________________________________________________________________________________
# fire2/relu_squeeze1x1dec (Activ (None, 88, 118, 16)  0           fire2/squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire2/expand1x1dec (Conv2D)     (None, 88, 118, 64)  1088        fire2/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire2/expand3x3dec (Conv2D)     (None, 88, 118, 64)  9280        fire2/relu_squeeze1x1dec[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand1x1dec (Activa (None, 88, 118, 64)  0           fire2/expand1x1dec[0][0]
# __________________________________________________________________________________________________
# fire2/relu_expand3x3dec (Activa (None, 88, 118, 64)  0           fire2/expand3x3dec[0][0]
# __________________________________________________________________________________________________
# fire2/concatdec (Concatenate)   (None, 88, 118, 128) 0           fire2/relu_expand1x1dec[0][0]
#                                                                  fire2/relu_expand3x3dec[0][0]
# __________________________________________________________________________________________________
# upsample3 (UpSampling2D)        (None, 176, 236, 128 0           fire2/concatdec[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 180, 240, 128 0           upsample3[0][0]
# __________________________________________________________________________________________________
# conv_prefinal (Conv2DTranspose) (None, 360, 480, 64) 73792       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# conv_final (Conv2D)             (None, 360, 480, 1)  577         conv_prefinal[0][0]
# ==================================================================================================
# Total params: 1,549,313
# Trainable params: 1,549,313
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
warnings.filterwarnings('ignore')

batch_size = 32
epochs = 5

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          shuffle=True,
          #callbacks = callbacks_list,
          validation_data=(x_test, y_test))
# Out:
# W0723 12:22:20.314453  2256 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 750 samples, validate on 251 samples
# Epoch 1/5
# 160/750 [=====>........................] - ETA: 14:47 - loss: 1.6885 - f1: 0.0000e+00 - iou: 0.0012
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-ab67ae7ea555> in <module>
#      10           shuffle=True,
#      11           #callbacks = callbacks_list,
# ---> 12           validation_data=(x_test, y_test))
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
